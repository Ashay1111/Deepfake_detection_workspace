# %%
from pathlib import Path
Path("video_detector/app/app.py").resolve().parents[1]
# Out:
# PosixPath('/Users/ashaypatel/Documents/Deepfake_detection_workspace/video_detector/notebooks/video_detector')
