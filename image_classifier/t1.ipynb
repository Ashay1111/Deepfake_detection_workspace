# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tarfile
from six.moves import urllib
import sklearn

# %%
fake_data_path = "real-and-fake-face-detection/real_and_fake_face/training_fake"
real_data_path = "real-and-fake-face-detection/real_and_fake_face/training_real"
fake_images = os.listdir(fake_data_path)
real_images = os.listdir(real_data_path)
print(f"Number of fake images: {len(fake_images)}")
print(f"Number of real images: {len(real_images)}")
# Out:
# Number of fake images: 960
# Number of real images: 1081

# %%
# Out:
# easy_143_0011.jpg
# mid_329_1110.jpg
# mid_257_1111.jpg
# mid_40_1111.jpg
# mid_41_1111.jpg
# real_00251.jpg
# real_00537.jpg
# real_00523.jpg
# real_00245.jpg
# real_00279.jpg
